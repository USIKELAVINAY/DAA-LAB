# %% [markdown]
# ITERATIVE AND RECURSIVE

# %%
import time

# Iterative Factorial
# Time Complexity: O(n)
# Space Complexity: O(1)
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# Recursive Factorial
# Time Complexity: O(n)
# Space Complexity: O(n) due to recursion stack
def factorial_recursive(n):
    if n <= 1:
        return 1

    return n * factorial_recursive(n - 1)


# Main program
n = int(input("Enter a non-negative integer (e.g., 20): "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")
else:

    # Measure Iterative Execution Time
    start_iter = time.perf_counter_ns()
    result_iter = factorial_iterative(n)
    end_iter = time.perf_counter_ns()

    duration_iter = end_iter - start_iter

    # Measure Recursive Execution Time
    start_rec = time.perf_counter_ns()
    result_rec = factorial_recursive(n)
    end_rec = time.perf_counter_ns()

    duration_rec = end_rec - start_rec

    # Output Results
    print("\n--- Results for", n, "! ---")

    print("Iterative Result :", result_iter)
    print("Iterative Time   :", duration_iter, "ns")
    print("Time Complexity  : O(n)")
    print("Space Complexity : O(1)")

    print("-------------------------------")

    print("Recursive Result :", result_rec)
    print("Recursive Time   :", duration_rec, "ns")
    print("Time Complexity  : O(n)")
    print("Space Complexity : O(n)")
# Out:
# Enter a non-negative integer (e.g., 20): 7
#
# --- Results for 7 ! ---
# Iterative Result : 5040
# Iterative Time   : 4900 ns
# Time Complexity  : O(n)
# Space Complexity : O(1)
# -------------------------------
# Recursive Result : 5040
# Recursive Time   : 2860 ns
# Time Complexity  : O(n)
# Space Complexity : O(n)

# %% [markdown]
# README

# %% [markdown]
#  Factorial Comparison
#
# Python program comparing **iterative and recursive factorial** implementations with their execution time and time/space complexity.
# It accepts **user input** and displays the factorial result and performance of both methods.
