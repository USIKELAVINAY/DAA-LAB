# %% [markdown]
# BUBBLE SORT

# %%
import time

# Bubble Sort function
def bubble_sort(arr):
    n = len(arr)

    for i in range(n):
        swapped = False

        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True

        # Stop if the array is already sorted
        if not swapped:
            break


# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter", n, "elements:")
for i in range(n):
    element = int(input(f"Element {i + 1}: "))
    arr.append(element)

print("\nOriginal array:", arr)

# Measure execution time
start_time = time.perf_counter()

bubble_sort(arr)

end_time = time.perf_counter()

# Display result
print("Sorted array:", arr)

execution_time = end_time - start_time

print(f"Execution time: {execution_time:.10f} seconds")

# Time complexity
print("\nTime Complexity:")
print("Best Case:    O(n)")
print("Average Case: O(n²)")
print("Worst Case:   O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter 5 elements:
# Element 1: 5
# Element 2: 6
# Element 3: 7
# Element 4: 8
# Element 5: 8
#
# Original array: [5, 6, 7, 8, 8]
# Sorted array: [5, 6, 7, 8, 8]
# Execution time: 0.0001343840 seconds
#
# Time Complexity:
# Best Case:    O(n)
# Average Case: O(n²)
# Worst Case:   O(n²)
# Space Complexity: O(1)

# %% [markdown]
# SELECTION SORT

# %%
import time

# Selection Sort function
def selection_sort(arr):
    n = len(arr)

    for i in range(n - 1):
        min_index = i

        # Find the smallest element
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        # Swap the smallest element with the first element
        arr[i], arr[min_index] = arr[min_index], arr[i]


# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter", n, "elements:")
for i in range(n):
    element = int(input(f"Element {i + 1}: "))
    arr.append(element)

print("\nOriginal array:", arr)

# Measure execution time
start_time = time.perf_counter()

selection_sort(arr)

end_time = time.perf_counter()

# Display result
print("Sorted array:", arr)

execution_time = end_time - start_time

print(f"Execution time: {execution_time:.10f} seconds")

# Time complexity
print("\nTime Complexity:")
print("Best Case:    O(n²)")
print("Average Case: O(n²)")
print("Worst Case:   O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 3
# Enter 3 elements:
# Element 1: 3
# Element 2: 3
# Element 3: 4
#
# Original array: [3, 3, 4]
# Sorted array: [3, 3, 4]
# Execution time: 0.0001242180 seconds
#
# Time Complexity:
# Best Case:    O(n²)
# Average Case: O(n²)
# Worst Case:   O(n²)
# Space Complexity: O(1)

# %% [markdown]
# INSERTION SORT

# %%
import time

# Insertion Sort function
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements greater than key one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key


# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter", n, "elements:")
for i in range(n):
    element = int(input(f"Element {i + 1}: "))
    arr.append(element)

print("\nOriginal array:", arr)

# Start execution time
start_time = time.perf_counter()

# Sort the array
insertion_sort(arr)

# End execution time
end_time = time.perf_counter()

# Display results
print("Sorted array:", arr)

execution_time = end_time - start_time

print(f"Execution time: {execution_time:.10f} seconds")

# Time Complexity
print("\nTime Complexity:")
print("Best Case:    O(n)")
print("Average Case: O(n²)")
print("Worst Case:   O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 3
# Enter 3 elements:
# Element 1: 4
# Element 2: 5
# Element 3: 6
#
# Original array: [4, 5, 6]
# Sorted array: [4, 5, 6]
# Execution time: 0.0000740730 seconds
#
# Time Complexity:
# Best Case:    O(n)
# Average Case: O(n²)
# Worst Case:   O(n²)
# Space Complexity: O(1)

# %% [markdown]
# QUICK SORT

# %%
import time

# Quick Sort function
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]

    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)


# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter", n, "elements:")
for i in range(n):
    element = int(input(f"Element {i + 1}: "))
    arr.append(element)

print("\nOriginal array:", arr)

# Start execution time
start_time = time.perf_counter()

# Sort the array
sorted_arr = quick_sort(arr)

# End execution time
end_time = time.perf_counter()

# Display results
print("Sorted array:", sorted_arr)

execution_time = end_time - start_time

print(f"Execution time: {execution_time:.10f} seconds")

# Time Complexity
print("\nTime Complexity:")
print("Best Case:    O(n log n)")
print("Average Case: O(n log n)")
print("Worst Case:   O(n²)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of elements: 3
# Enter 3 elements:
# Element 1: 4
# Element 2: 5
# Element 3: 5
#
# Original array: [4, 5, 5]
# Sorted array: [4, 5, 5]
# Execution time: 0.0001125310 seconds
#
# Time Complexity:
# Best Case:    O(n log n)
# Average Case: O(n log n)
# Worst Case:   O(n²)
# Space Complexity: O(n)

# %% [markdown]
# MERGE SORT

# %%
import time

# Merge Sort function
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    # Find the middle
    mid = len(arr) // 2

    # Divide the array
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    # Merge the two sorted halves
    return merge(left, right)


# Merge function
def merge(left, right):
    result = []
    i = 0
    j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    # Add remaining elements
    result.extend(left[i:])
    result.extend(right[j:])

    return result


# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter", n, "elements:")
for i in range(n):
    element = int(input(f"Element {i + 1}: "))
    arr.append(element)

print("\nOriginal array:", arr)

# Start execution time
start_time = time.perf_counter()

# Sort the array
sorted_arr = merge_sort(arr)

# End execution time
end_time = time.perf_counter()

# Display results
print("Sorted array:", sorted_arr)

execution_time = end_time - start_time

print(f"Execution time: {execution_time:.10f} seconds")

# Time Complexity
print("\nTime Complexity:")
print("Best Case:    O(n log n)")
print("Average Case: O(n log n)")
print("Worst Case:   O(n log n)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of elements: 4
# Enter 4 elements:
# Element 1: 5
# Element 2: 6
# Element 3: 7
# Element 4: 7
#
# Original array: [5, 6, 7, 7]
# Sorted array: [5, 6, 7, 7]
# Execution time: 0.0000897240 seconds
#
# Time Complexity:
# Best Case:    O(n log n)
# Average Case: O(n log n)
# Worst Case:   O(n log n)
# Space Complexity: O(n)
